# %% [markdown]
# <a href="https://colab.research.google.com/github/soupydoodles/Chocos/blob/main/Copy_of_discord_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install discord.py
# !pip install tinydb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.7 MB/s eta 0:00:00
# ...

# %%
# !pip install nest-asyncio
import nest_asyncio
nest_asyncio.apply()

# %%
discord_token = "MTEzMzcxNDU1NzEyNzM3Mjg3Mg.G8_WQW.0fQkpVUo5x-Wt-S01jJk08ap_APDc1Q4Y639R8"
#enter your discord bot's token in the double quotes

# %%
from discord.ext import commands
import discord
from tinydb import TinyDB, Query

intents = discord.Intents.all()

# %%
# demonstrate all data available in on_message
bot = commands.Bot(command_prefix="!",intents = intents) #anything followed by the prefix will be considered a command
def run():

    @bot.event
    async def on_message(message: discord.Message):

        content = message.content
        author = message.author
        channel = message.channel

        #print(message)
        print(author)
        print(channel)
        print(content)
    #dont copy next line
    bot.run(discord_token)

run()
# Out:
# WARNING:discord.client:PyNaCl is not installed, voice will NOT be supported
# 2023-08-23 12:04:01 INFO     discord.client logging in using static token
# INFO:discord.client:logging in using static token
# 2023-08-23 12:04:02 INFO     discord.gateway Shard ID None has connected to Gateway (Session ID: 1be2ab59116b44b36114d2fdfd0d6773).
# INFO:discord.gateway:Shard ID None has connected to Gateway (Session ID: 1be2ab59116b44b36114d2fdfd0d6773).
# farad_addy_cage#7596
# home
# hey

# %%
#developing bot functionality
bot = commands.Bot(command_prefix="^",intents = intents)
def run():

    @bot.event
    async def on_message(message: discord.Message):

        content = message.content
        mentions = message.mentions
        author = message.author
        #print(mentions)
        if 'fuck' or 'shit' or 'bitch' or 'fucker' or 'motherfucker' or 'nigger' or 'nigga' or 'dick' or 'dickhead' or 'cunt' or 'fatso' or 'bastard' or 'whore' or 'slut' in content:
            await message.channel.send("{} please refrain from using offensive content".format(author.name))
            print(author.name)

    bot.run(discord_token)

run()
# Out:
# 2023-08-23 16:21:04 INFO     discord.client logging in using static token
# 2023-08-23 16:21:04 INFO     discord.client logging in using static token
# 2023-08-23 16:21:04 INFO     discord.client logging in using static token
# 2023-08-23 16:21:04 INFO     discord.client logging in using static token
# 2023-08-23 16:21:04 INFO     discord.client logging in using static token
# 2023-08-23 16:21:04 INFO     discord.client logging in using static token
# 2023-08-23 16:21:04 INFO     discord.client logging in using static token
# 2023-08-23 16:21:04 INFO     discord.client logging in using static token
# 2023-08-23 16:21:04 INFO     discord.client logging in using static token
# 2023-08-23 16:21:04 INFO     discord.client logging in using static token
# 2023-08-23 16:21:04 INFO     discord.client logging in using static token
# 2023-08-23 16:21:04 INFO     discord.client logging in using static token
# 2023-08-23 16:21:04 INFO     discord.client logging in using static token
# ...

# %%
#using commands
bot = commands.Bot(command_prefix="^",intents = intents)


def run():

    @bot.command()
    async def repeat(ctx, msg="WHAT"):
        await ctx.send(msg)

    @bot.command()
    async def thanks(ctx, mention):
        await ctx.send("{} has been thanked".format(mention))
        print(mention)


    @bot.group()
    async def greet(ctx):
        if not ctx.invoked_subcommand:
            await ctx.send("Please give me a subcommand")

    @greet.command()
    async def thanks(ctx,mention):
        await ctx.send("{} was thanked".format(mention))

    @greet.command()
    async def welcome(ctx,mention):
        await ctx.send("{} was welcomed".format(mention))


    bot.run(discord_token)

run()
# Out:
# 2023-08-23 15:51:57 INFO     discord.client logging in using static token
# 2023-08-23 15:51:57 INFO     discord.client logging in using static token
# 2023-08-23 15:51:57 INFO     discord.client logging in using static token
# 2023-08-23 15:51:57 INFO     discord.client logging in using static token
# 2023-08-23 15:51:57 INFO     discord.client logging in using static token
# 2023-08-23 15:51:57 INFO     discord.client logging in using static token
# 2023-08-23 15:51:57 INFO     discord.client logging in using static token
# 2023-08-23 15:51:57 INFO     discord.client logging in using static token
# 2023-08-23 15:51:57 INFO     discord.client logging in using static token
# 2023-08-23 15:51:57 INFO     discord.client logging in using static token
# 2023-08-23 15:51:57 INFO     discord.client logging in using static token
# 2023-08-23 15:51:57 INFO     discord.client logging in using static token
# 2023-08-23 15:51:57 INFO     discord.client logging in using static token
# ...

# %%
#trying to maintain a record of user activity
thank_points = {}
bot = commands.Bot(command_prefix="^",intents = intents)


def run():

    @bot.event
    async def on_ready():
        print(thank_points)

    @bot.command()
    async def thanks(ctx, mention):
        await ctx.send("{} has been thanked".format(mention))
        print(mention)
        #print(ctx.author.id)
        await ctx.send("{} is the user".format(mention))

        if mention not in thank_points.keys():
            thank_points[mention] = 1
        else:
            thank_points[mention] = thank_points[mention] + 1

        print(thank_points)

    @bot.command()
    async def thank_leaderboard(ctx):
        # Creating an embed object
        embed = discord.Embed(
            title="Leadrerboard",
            description="This is the description of the embed.",
            color=discord.Color.red()  # You can customize the color of the embed
        )
        #embed.set_author(name="Author Name", icon_url=ctx.author.avatar_url)
        embed.set_thumbnail(url="https://t3.ftcdn.net/jpg/00/92/53/56/360_F_92535664_IvFsQeHjBzfE6sD4VHdO8u5OHUSc6yHF.jpg")  # URL of the thumbnail image

        for key,value in thank_points.items():
            embed.add_field(name=key, value=value, inline=False)

        # Sending the embed
        await ctx.send(embed=embed)
        print(thank_points)





    bot.run(discord_token)

run()
# Out:
# 2023-08-23 15:54:09 INFO     discord.client logging in using static token
# 2023-08-23 15:54:09 INFO     discord.client logging in using static token
# 2023-08-23 15:54:09 INFO     discord.client logging in using static token
# 2023-08-23 15:54:09 INFO     discord.client logging in using static token
# 2023-08-23 15:54:09 INFO     discord.client logging in using static token
# 2023-08-23 15:54:09 INFO     discord.client logging in using static token
# 2023-08-23 15:54:09 INFO     discord.client logging in using static token
# 2023-08-23 15:54:09 INFO     discord.client logging in using static token
# 2023-08-23 15:54:09 INFO     discord.client logging in using static token
# 2023-08-23 15:54:09 INFO     discord.client logging in using static token
# 2023-08-23 15:54:09 INFO     discord.client logging in using static token
# 2023-08-23 15:54:09 INFO     discord.client logging in using static token
# 2023-08-23 15:54:09 INFO     discord.client logging in using static token
# ...

# %%
#trying to maintain a record of user activity
thank_points = TinyDB('bot_db.json')
User = Query()
bot = commands.Bot(command_prefix="^",intents = intents)


def run():

    @bot.event
    async def on_ready():
        print(thank_points.all())

    @bot.command()
    async def thanks(ctx, mention):
        await ctx.send("{} has been thanked".format(mention))
        print(mention)
        #print(ctx.author.id)
        await ctx.send("{} is the user".format(mention))

        if not thank_points.contains(User['id']==mention):
            thank_points.insert({'id':mention,'points':1})
        else:
            [result] = thank_points.search(User['id']==mention)
            thank_points.update({'points':(result['points']+1)},User['id']==mention)

        print(thank_points.all())

    @bot.command()
    async def thank_leaderboard(ctx):
        # Creating an embed object
        embed = discord.Embed(
            title="Leadrerboard",
            description="This is the description of the embed.",
            color=discord.Color.blue()  # You can customize the color of the embed
        )
        #embed.set_author(name="Author Name", icon_url=ctx.author.avatar_url)
        embed.set_thumbnail(url="https://media.giphy.com/media/joYf3Ba2phD15ch9Nt/giphy.gif")  #URL of the thumbnail image

        for item in sorted(thank_points.all(),key=lambda x: x['points'],reverse = True):
            user_id = item['id']
            user = await bot.fetch_user(int(user_id.strip("<@!>")))

            embed.add_field(name=user.name, value=item['points'], inline=False)
        #sort in increasing order
        # Sending the embed
        await ctx.send(embed=embed)

    bot.run(discord_token)

run()
# Out:
# 2023-07-26 12:36:22 INFO     discord.client logging in using static token
# 2023-07-26 12:36:22 INFO     discord.client logging in using static token
# 2023-07-26 12:36:22 INFO     discord.client logging in using static token
# 2023-07-26 12:36:22 INFO     discord.client logging in using static token
# 2023-07-26 12:36:22 INFO     discord.client logging in using static token
# 2023-07-26 12:36:22 INFO     discord.client logging in using static token
# 2023-07-26 12:36:22 INFO     discord.client logging in using static token
# 2023-07-26 12:36:22 INFO     discord.client logging in using static token
# 2023-07-26 12:36:22 INFO     discord.client logging in using static token
# 2023-07-26 12:36:22 INFO     discord.client logging in using static token
# 2023-07-26 12:36:22 INFO     discord.client logging in using static token
# 2023-07-26 12:36:22 INFO     discord.client logging in using static token
# 2023-07-26 12:36:22 INFO     discord.client logging in using static token
# ...

# %%
#discord slash commands

thank_points = TinyDB('bot_db.json')
User = Query()
bot = commands.Bot(command_prefix="^",intents = intents)


def run():

    @bot.event
    async def on_ready():
        print(thank_points.all())

        await bot.tree.sync()

    @bot.hybrid_command()
    async def thanks(ctx, men):
        await ctx.send("{} has been thanked".format(men))
        print(men)
        #print(ctx.author.id)
        await ctx.send("{} is the user".format(men))

        if not thank_points.contains(User['id']==men):
            thank_points.insert({'id':men,'points':1})
        else:
            [result] = thank_points.search(User['id']==men)
            thank_points.update({'points':(result['points']+1)},User['id']==men)

        print(thank_points.all())

    @bot.hybrid_command()
    async def thank_leaderboard(ctx):
        # Creating an embed object
        embed = discord.Embed(
            title="lauda-board",
            description="chup kar vanar",
            color=discord.Color.blue()  # You can customize the color of the embed
        )
        #embed.set_author(name="Author Name", icon_url=ctx.author.avatar_url)
        embed.set_thumbnail(url="https://media.giphy.com/media/aFTt8wvDtqKCQ/giphy.gif")  #URL of the thumbnail image

        for item in sorted(thank_points.all(),key=lambda x: x['points'],reverse = True):
            user_id = item['id']
            user = await bot.fetch_user(int(user_id.strip("<@!>")))
            embed.add_field(name=user.name, value=item['points'], inline=False)

        # Sending the embed
        await ctx.send(embed=embed)





    bot.run(discord_token)

run()
# Out:
# 2023-07-26 12:46:21 INFO     discord.client logging in using static token
# 2023-07-26 12:46:21 INFO     discord.client logging in using static token
# 2023-07-26 12:46:21 INFO     discord.client logging in using static token
# 2023-07-26 12:46:21 INFO     discord.client logging in using static token
# 2023-07-26 12:46:21 INFO     discord.client logging in using static token
# 2023-07-26 12:46:21 INFO     discord.client logging in using static token
# 2023-07-26 12:46:21 INFO     discord.client logging in using static token
# 2023-07-26 12:46:21 INFO     discord.client logging in using static token
# 2023-07-26 12:46:21 INFO     discord.client logging in using static token
# 2023-07-26 12:46:21 INFO     discord.client logging in using static token
# 2023-07-26 12:46:21 INFO     discord.client logging in using static token
# 2023-07-26 12:46:21 INFO     discord.client logging in using static token
# 2023-07-26 12:46:21 INFO     discord.client logging in using static token
# ...
